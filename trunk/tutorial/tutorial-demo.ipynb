# %% [markdown]
# #PhlyGreen Tutorial

# %% [markdown]
# Import packages

# %%
import sys
sys.path.insert(0,'../')
import PhlyGreen as pg
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create instances of subsystems. Each one of those requires an Aircraft object as argument. By passing (None) as argument, we are creating empty objects (for the moment).

# %%
powertrain = pg.Systems.Powertrain.Powertrain(None)
structures = pg.Systems.Structures.Structures(None)
aerodynamics = pg.Systems.Aerodynamics.Aerodynamics(None)
performance = pg.Performance.Performance(None)
mission = pg.Mission.Mission(None)
weight = pg.Weight.Weight(None)
constraint = pg.Constraint.Constraint(None)
welltowake = pg.WellToWake.WellToWake(None)
battery = pg.Systems.Battery.Battery(None)

# %% [markdown]
# Create instance of Aircraft object.

# %%
myaircraft = pg.Aircraft(powertrain, structures, aerodynamics, performance, mission, weight, constraint, welltowake, battery)

# %% [markdown]
# Create the connections with its subsystems.

# %%
powertrain.aircraft = myaircraft
structures.aircraft = myaircraft
aerodynamics.aircraft = myaircraft
mission.aircraft = myaircraft
performance.aircraft = myaircraft
weight.aircraft = myaircraft
constraint.aircraft = myaircraft
welltowake.aircraft = myaircraft
battery.aircraft = myaircraft

# %% [markdown]
# Define input dictionaries

# %%
ConstraintsInput = {'DISA': 0.,
                    'Cruise': {'Speed': 0.5, 'Speed Type':'Mach', 'Beta': 0.95, 'Altitude': 8000.},
                    'AEO Climb': {'Speed': 210, 'Speed Type':'KCAS', 'Beta': 0.97, 'Altitude': 6000., 'ROC': 5},
                    'OEI Climb': {'Speed': 1.2*34.5, 'Speed Type': 'TAS', 'Beta': 1., 'Altitude': 0., 'Climb Gradient': 0.021},
                    'Take Off': {'Speed': 90, 'Speed Type': 'TAS', 'Beta': 1., 'Altitude': 100., 'kTO': 1.2, 'sTO': 950},
                    'Landing':{'Speed': 59., 'Speed Type': 'TAS', 'Altitude': 500.},
                    'Turn':{'Speed': 210, 'Speed Type': 'KCAS', 'Beta': 0.9, 'Altitude': 5000, 'Load Factor': 1.1},
                    'Ceiling':{'Speed': 0.5, 'Beta': 0.8, 'Altitude': 9500, 'HT': 0.5},
                    'Acceleration':{'Mach 1': 0.3, 'Mach 2':0.4, 'DT': 180, 'Altitude': 6000, 'Beta': 0.9}}

# %%
MissionInput = {'Range Mission': 800,  #nautical miles
                'Range Diversion': 220,  #nautical miles
                'Beta start': 0.97,
                'Payload Weight': 4560,  #Kg
                'Crew Weight': 500}  #Kg

# %%
MissionStages = {'Takeoff': {'Supplied Power Ratio':{'phi': 0.5}},
                'Climb1': {'type': 'ConstantRateClimb', 'input': {'CB': 0.16, 'Speed': 77, 'StartAltitude': 100, 'EndAltitude': 1500}, 'Supplied Power Ratio':{'phi_start': 0.5, 'phi_end':0.1 }},
                 'Climb2': {'type': 'ConstantRateClimb', 'input': {'CB': 0.08, 'Speed': 120, 'StartAltitude': 1500, 'EndAltitude': 4500}, 'Supplied Power Ratio':{'phi_start': 0.1, 'phi_end':0.05 }},
                 'Climb3': {'type': 'ConstantRateClimb', 'input': {'CB': 0.07, 'Speed': 125, 'StartAltitude': 4500, 'EndAltitude': 8000}, 'Supplied Power Ratio':{'phi_start': 0.05, 'phi_end':0.00  }},
                 'Cruise': {'type': 'ConstantMachCruise', 'input':{ 'Mach': 0.4, 'Altitude': 8000}, 'Supplied Power Ratio':{'phi_start': 0, 'phi_end':0 }},
                 'Descent1': {'type': 'ConstantRateDescent', 'input':{'CB': -0.04, 'Speed': 90, 'StartAltitude': 8000, 'EndAltitude': 200}, 'Supplied Power Ratio':{'phi_start': 0, 'phi_end':0  }}}

DiversionStages = {'Climb1': {'type': 'ConstantRateClimb', 'input': {'CB': 0.08, 'Speed': 110, 'StartAltitude': 200, 'EndAltitude': 3100}, 'Supplied Power Ratio':{'phi_start': 0, 'phi_end':0  }},
                 'Cruise': {'type': 'ConstantMachCruise', 'input':{ 'Mach': 0.35, 'Altitude': 3100}, 'Supplied Power Ratio':{'phi_start': 0, 'phi_end':0 }},
                 'Descent1': {'type': 'ConstantRateDescent', 'input':{'CB': -0.04, 'Speed': 90, 'StartAltitude': 3100, 'EndAltitude': 200}, 'Supplied Power Ratio':{'phi_start': 0, 'phi_end':0 }}}

# %%
EnergyInput = {'Ef': 43.5*10**6,
                   'Contingency Fuel': 130,
                   'Eta Gas Turbine': 0.22,
                   'Eta Gearbox': 0.96,
                   'Eta Propulsive': 0.9,
                   'Eta Electric Motor 1': 0.96,    #for serial config
                   'Eta Electric Motor 2': 0.96,    #for serial config
                   'Eta Electric Motor': 0.98,      #for parallel config
                   'Eta PMAD': 0.99,
                   'Specific Power Powertrain': [3900,7700],
                   'Specific Power PMAD': [2200,2200,2200],
                   'PowertoWeight Battery': 35, 
                   'PowertoWeight Powertrain': [150,33],
                   'PowertoWeight PMAD': 0
                   }
                   
CellModel = 'SAMSUNG_LIR18650'

# %%
AerodynamicsInput = {'AnalyticPolar': {'type': 'Quadratic', 'input': {'AR': 11, 'e_osw': 0.8}},
                    'Take Off Cl': 1.9,
                     'Landing Cl': 1.9,
                     'Minimum Cl': 0.20,
                     'Cd0': 0.017}

# %% [markdown]
# Import input dictionaries

# %%
myaircraft.ConstraintsInput = ConstraintsInput
myaircraft.AerodynamicsInput = AerodynamicsInput
myaircraft.MissionInput = MissionInput
myaircraft.MissionStages = MissionStages
myaircraft.DiversionStages = DiversionStages
myaircraft.EnergyInput = EnergyInput
myaircraft.CellModel = CellModel

# %% [markdown]
# Set aircraft power configuration

# %%
myaircraft.Configuration = 'Hybrid'
myaircraft.HybridType = 'Parallel'
myaircraft.AircraftType = 'ATR'

# %% [markdown]
# Set inputs

# %%
# Initialize Constraint Analysis
myaircraft.constraint.SetInput()

# Initialize Mission profile and Analysis
myaircraft.mission.InitializeProfile()
myaircraft.mission.SetInput()

# Initialize Aerodynamics subsystem
myaircraft.aerodynamics.SetInput()

# Initialize Powertrain
myaircraft.powertrain.SetInput()

# Initialize Weight Estimator
myaircraft.weight.SetInput()

#Initialize Battery Configurator
myaircraft.battery.SetInput()
# Out:
# Warning: Eta Gas Turbine model unset. Using constant model
# Warning: Eta Propulsive model unset. Using constant model

# %% [markdown]
# Either run the Constraint Analysis....

# %%
myaircraft.constraint.FindDesignPoint()
print('----------------------------------------')
print('Design W/S: ',myaircraft.DesignWTOoS)
print('Design P/W: ',myaircraft.DesignPW)
print('----------------------------------------')
# Out:
# ----------------------------------------
# Design W/S:  3293.8228228228227
# Design P/W:  194.90567908431782
# ----------------------------------------

# %%
plt.plot(myaircraft.constraint.WTOoS,myaircraft.constraint.PWCruise, label='Cruise')
plt.plot(myaircraft.constraint.WTOoS,myaircraft.constraint.PWTakeOff, label='Take Off')
plt.plot(myaircraft.constraint.WTOoS,myaircraft.constraint.PWAEOClimb, label='Climb')
plt.plot(myaircraft.constraint.WTOoS,myaircraft.constraint.PWOEIClimb, label='Climb OEI')
plt.plot(myaircraft.constraint.WTOoS,myaircraft.constraint.PWTurn, label='Turn')
plt.plot(myaircraft.constraint.WTOoS,myaircraft.constraint.PWCeiling, label='Ceiling')
plt.plot(myaircraft.constraint.WTOoS,myaircraft.constraint.PWAcceleration, label='Acceleration')
plt.plot(myaircraft.constraint.WTOoSLanding,myaircraft. constraint.PWLanding, label='Landing')
plt.plot(myaircraft.DesignWTOoS, myaircraft.DesignPW, marker='o', markersize = 10, markerfacecolor = 'red', markeredgecolor = 'black')
# plt.plot(performance.WTOoSTorenbeek, performance.PWTorenbeek, label='Torenbeek')
plt.ylim([0, 300])
plt.xlim([0, 7000])
plt.legend()
plt.grid(visible=True)
plt.xlabel('$W_{TO}/S$')
plt.ylabel('$P/W_{TO}$')
plt.show()

# %% [markdown]
# ... or assign a wing loading

# %%
# myaircraft.DesignWTOoS = 3323

# %% [markdown]
# Run Mission analysis to define the aircraft's masses

# %%
myaircraft.weight.WeightEstimation()
# Out:
# 341.0
# /home/john/Documents/SAPIENZA/THESIS/REPOS/PhlyGreen/trunk/tutorial/../PhlyGreen/Systems/Battery/Battery.py:227: RuntimeWarning: invalid value encountered in scalar power
#   U_out = (U_oc + (U_oc**2 - 4 * Power_out * Resistance)**0.5)/2 #this comes from the analytical solution of P_out = U_out * I_out
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 myaircraft.weight.WeightEstimation()
#
# File ~/Documents/SAPIENZA/THESIS/REPOS/PhlyGreen/trunk/tutorial/../PhlyGreen/Weight/Weight.py:39, in Weight.WeightEstimation(self)
#      33          return self.Traditional()
#      36 elif self.aircraft.Configuration == 'Hybrid':
# ---> 39          return self.Hybrid()
#      41 else:
#      42          return "Try a different configuration..."
#
# File ~/Documents/SAPIENZA/THESIS/REPOS/PhlyGreen/trunk/tutorial/../PhlyGreen/Weight/Weight.py:104, in Weight.Hybrid(self)
#     100             self.final_reserve = 0.05*self.Wf
#     102         return (self.Wf + self.final_reserve + self.WBat + self.WPT + self.WStructure + self.WPayload + self.WCrew - WTO)
# --> 104 self.WTO = brenth(func, 10000, 300000, xtol=0.1)
#
# File /usr/lib/python3/dist-packages/scipy/optimize/_zeros_py.py:893, in brenth(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     891 if rtol < _rtol:
#     892     raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 893 r = _zeros._brenth(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     894 return results_c(full_output, r)
#
# File ~/Documents/SAPIENZA/THESIS/REPOS/PhlyGreen/trunk/tutorial/../PhlyGreen/Weight/Weight.py:68, in Weight.Hybrid.<locals>.func(WTO)
#      66 def func(WTO):
# ---> 68         self.TotalEnergies = self.aircraft.mission.EvaluateMission(WTO)
#      69         self.Wf = self.TotalEnergies[0]/self.ef
#      71         '''#maximum power for the battery, Max_PBat does not include takeoff power
#      72         if self.aircraft.mission.Max_PBat > self.aircraft.mission.TO_PBat:
#      73             self.MaxBatPwr = self.aircraft.mission.Max_PBat
#    (...)
#      82         # this is because peak power is only representative of one SOC of the battery,
#      83         # while parallel cell nr is representative of the entire power profile over the mission'''
#
# File ~/Documents/SAPIENZA/THESIS/REPOS/PhlyGreen/trunk/tutorial/../PhlyGreen/Mission/Mission.py:76, in Mission.EvaluateMission(self, WTO)
#      73     return self.TraditionalConfiguration(WTO)
#      75 elif self.aircraft.Configuration == 'Hybrid':
# ---> 76     return self.HybridConfiguration(WTO)
#      78 else:
#      79     raise Exception("Unknown aircraft configuration: %s" %self.aircraft.Configuration)
#
# File ~/Documents/SAPIENZA/THESIS/REPOS/PhlyGreen/trunk/tutorial/../PhlyGreen/Mission/Mission.py:205, in Mission.HybridConfiguration(self, WTO)
#     203 times = np.append(self.profile.Breaks,self.profile.MissionTime2)
#     204 for i in range(len(times)-1):
# --> 205     sol = integrate.solve_ivp(model,[times[i], times[i+1]], y0, method=method, rtol=rtol)
#     206     self.integral_solution.append(sol)
#     207     y0 = [sol.y[0][-1],sol.y[1][-1],sol.y[2][-1],sol.y[3][-1]]
#
# File /usr/lib/python3/dist-packages/scipy/integrate/_ivp/ivp.py:546, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     543 if method in METHODS:
#     544     method = METHODS[method]
# --> 546 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     548 if t_eval is None:
#     549     ts = [t0]
#
# File /usr/lib/python3/dist-packages/scipy/integrate/_ivp/bdf.py:198, in BDF.__init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, jac, jac_sparsity, vectorized, first_step, **extraneous)
#     196 f = self.fun(self.t, self.y)
#     197 if first_step is None:
# --> 198     self.h_abs = select_initial_step(self.fun, self.t, self.y, f,
#     199                                      self.direction, 1,
#     200                                      self.rtol, self.atol)
#     201 else:
#     202     self.h_abs = validate_first_step(first_step, t0, t_bound)
#
# File /usr/lib/python3/dist-packages/scipy/integrate/_ivp/common.py:111, in select_initial_step(fun, t0, y0, f0, direction, order, rtol, atol)
#     108     h0 = 0.01 * d0 / d1
#     110 y1 = y0 + h0 * direction * f0
# --> 111 f1 = fun(t0 + h0 * direction, y1)
#     112 d2 = norm((f1 - f0) / scale) / h0
#     114 if d1 <= 1e-15 and d2 <= 1e-15:
#
# File /usr/lib/python3/dist-packages/scipy/integrate/_ivp/base.py:138, in OdeSolver.__init__.<locals>.fun(t, y)
#     136 def fun(t, y):
#     137     self.nfev += 1
# --> 138     return self.fun_single(t, y)
#
# File /usr/lib/python3/dist-packages/scipy/integrate/_ivp/base.py:20, in check_arguments.<locals>.fun_wrapped(t, y)
#      19 def fun_wrapped(t, y):
# ---> 20     return np.asarray(fun(t, y), dtype=dtype)
#
# File ~/Documents/SAPIENZA/THESIS/REPOS/PhlyGreen/trunk/tutorial/../PhlyGreen/Mission/Mission.py:166, in Mission.HybridConfiguration.<locals>.model(t, y)
#     164 Beta = y[2] #aircraft mass fraction
#     165 SOC = y[3]  #battery state of charge
# --> 166 Ppropulsive = PowerPropulsive(Beta,t)
#     167 PRatio = self.aircraft.powertrain.Hybrid(self.aircraft.mission.profile.SuppliedPowerRatio(t),self.profile.Altitude(t),self.profile.Velocity(t),Ppropulsive) #takes in all the mission segments and finds the required power ratio for the current time of the mission
#     169 dEFdt = Ppropulsive * PRatio[0] #fuel power output
#
# File ~/Documents/SAPIENZA/THESIS/REPOS/PhlyGreen/trunk/tutorial/../PhlyGreen/Mission/Mission.py:157, in Mission.HybridConfiguration.<locals>.PowerPropulsive(Beta, t)
#     155 def PowerPropulsive(Beta,t):
# --> 157     PPoWTO = self.aircraft.performance.PoWTO(self.aircraft.DesignWTOoS,Beta,self.profile.PowerExcess(t),1,self.profile.Altitude(t),self.DISA,self.profile.Velocity(t),'TAS')
#     159     return PPoWTO * WTO
#
# File ~/Documents/SAPIENZA/THESIS/REPOS/PhlyGreen/trunk/tutorial/../PhlyGreen/Performance/Performance.py:128, in Performance.PoWTO(self, WTOoS, beta, Ps, n, altitude, DISA, speed, speedtype)
#     127 def PoWTO(self,WTOoS,beta,Ps,n,altitude,DISA,speed,speedtype):      # W/Kg
# --> 128     self.set_speed(altitude,speed,speedtype,DISA)
#     129     q = 0.5 * ISA.atmosphere.RHOstd(altitude,DISA) * self.TAS**2
#     130     Cl = n * beta * WTOoS / q
#
# File ~/Documents/SAPIENZA/THESIS/REPOS/PhlyGreen/trunk/tutorial/../PhlyGreen/Performance/Performance.py:95, in Performance.set_speed(self, altitude, speed, speedtype, DISA)
#      92     self.KCAS = Units.MtoKN(self.CAS)
#      94 elif speedtype == 'TAS':
# ---> 95     self.Mach = Speed.TAS2Mach(speed,altitude,DISA)
#      96     self.TAS = speed
#      97     self.CAS = Speed.TAS2CAS(speed,altitude,DISA)
#
# File ~/Documents/SAPIENZA/THESIS/REPOS/PhlyGreen/trunk/tutorial/../PhlyGreen/Performance/Performance.py:31, in Performance.Mach(self, value)
#      29 self._Mach = value
#      30 if(isinstance(value, numbers.Number) and (value <= 0 or value > 1.0)):
# ---> 31     raise ValueError("Error: Illegal Mach number: %e. Exiting" %value)
#
# ValueError: Error: Illegal Mach number: 0.000000e+00. Exiting

# %% [markdown]
# Wing surface can be readily estimated as S = WTO/(WTO/S)

# %%
myaircraft.WingSurface = myaircraft.weight.WTO / myaircraft.DesignWTOoS * 9.81

# %% [markdown]
# A summary of the preliminary design:

# %%
print('Fuel mass (trip + altn) [Kg]: ', myaircraft.weight.Wf)
print('Block Fuel mass [Kg]:         ', myaircraft.weight.Wf + myaircraft.weight.final_reserve)
print('Battery mass [Kg]:            ', myaircraft.weight.WBat)
print('Structure [Kg]:               ', myaircraft.weight.WStructure)
print('Powertrain mass [Kg]:         ',myaircraft.weight.WPT)
print('Empty Weight [Kg]:            ', myaircraft.weight.WPT + myaircraft.weight.WStructure + myaircraft.weight.WCrew + myaircraft.weight.WBat)
print('Zero Fuel Weight [Kg]:        ', myaircraft.weight.WPT + myaircraft.weight.WStructure + myaircraft.weight.WCrew + myaircraft.weight.WBat + myaircraft.weight.WPayload)
print('----------------------------------------')
print('Takeoff Weight: ', myaircraft.weight.WTO)
if myaircraft.WellToTankInput is not None:
    print('Source Energy: ', myaircraft.welltowake.SourceEnergy/1.e6,' MJ')
    print('Psi: ', myaircraft.welltowake.Psi)
print('Wing Surface: ', myaircraft.WingSurface, ' m^2')
print('TakeOff engine shaft peak power [kW]:      ', myaircraft.mission.TO_PP/1000.)
print('Climb/cruise engine shaft peak power [kW]: ', myaircraft.mission.Max_PEng/1000.)
print('TakeOff battery peak power [kW]:           ', myaircraft.mission.TO_PBat/1000.)
print('Climb/cruise battery peak power [kW]:      ', myaircraft.mission.Max_PBat/1000.)
print('Cells total energy',myaircraft.battery.total_cells_energy)
print('Cells power',myaircraft.battery.parallel_nr_power)

print('Sizing phase for battery: ', 'Cruise energy' if myaircraft.battery.energy_or_power == 'energy' else 'Cruise peak power' if myaircraft.weight.TOPwr_or_CruisePwr == 'cruise' else 'Takeoff peak power'  ) #uncomment when i add a mechanism for seeing which constraint drove what thing in the battery sizing
print('Sizing phase for thermal powertrain ', 'Climb/Cruise peak power' if myaircraft.mission.Max_PEng > myaircraft.mission.TO_PP else 'Takeoff peak power'  )
print('Sizing phase for electric powertrain ', 'Climb/Cruise peak power' if myaircraft.mission.Max_PBat > myaircraft.mission.TO_PBat else 'Takeoff peak power'  )

# %% [markdown]
# Some plots:

# %%
times = np.linspace(0,mission.profile.MissionTime2,num = 1000)
plt.plot(times/60,[mission.profile.SuppliedPowerRatio(t) for t in times], 'b')
#plt.plot(myaircraft.mission.profile.Breaks,np.ones(6)*0.05, '*')
plt.grid(visible=True)
plt.xlabel('t [min]')
plt.ylabel('Phi')
plt.show()

# %%
times = np.array([])
Ef = np.array([])
Ebat = np.array([])
beta = np.array([])
for array in mission.integral_solution:
    times = np.concatenate([times, array.t])
    Ef = np.concatenate([Ef, array.y[0]])
    Ebat = np.concatenate([Ebat, array.y[1]])
    beta = np.concatenate([beta, array.y[2]])

# %% [markdown]
# Takeoff propulsive power

# %%
myaircraft.performance.TakeOff(myaircraft.DesignWTOoS,myaircraft.constraint.TakeOffConstraints['Beta'], myaircraft.constraint.TakeOffConstraints['Altitude'],myaircraft.constraint.TakeOffConstraints['kTO'], myaircraft.constraint.TakeOffConstraints['sTO'], myaircraft.constraint.DISA, myaircraft.constraint.TakeOffConstraints['Speed'], myaircraft.constraint.TakeOffConstraints['Speed Type'])

# %% [markdown]
# Maximum mission Propusive Power over Takeoff Mass

# %%
max([myaircraft.performance.PoWTO(myaircraft.DesignWTOoS,beta[t],myaircraft.mission.profile.PowerExcess(times[t]),1,myaircraft.mission.profile.Altitude(times[t]),myaircraft.mission.DISA,myaircraft.mission.profile.Velocity(times[t]),'TAS') for t in range(len(times))])

# %%
plt.plot(times/60,[myaircraft.performance.PoWTO(myaircraft.DesignWTOoS,beta[t],myaircraft.mission.profile.PowerExcess(times[t]),1,myaircraft.mission.profile.Altitude(times[t]),myaircraft.mission.DISA,myaircraft.mission.profile.Velocity(times[t]),'TAS') for t in range(len(times))], 'b')
plt.grid(visible=True)
plt.xlabel('t [min]')
plt.ylabel('Pp/W')
plt.show()

# %%
plt.plot(times/60,[(myaircraft.weight.WTO/1000) * myaircraft.performance.PoWTO(myaircraft.DesignWTOoS,beta[t],myaircraft.mission.profile.PowerExcess(times[t]),1,myaircraft.mission.profile.Altitude(times[t]),myaircraft.mission.DISA,myaircraft.mission.profile.Velocity(times[t]),'TAS') for t in range(len(times))], 'b')
plt.grid(visible=True)
plt.xlabel('t [min]')
plt.ylabel('Pp [kW]')
plt.show()

# %%
plt.plot(times,Ef, 'b')
#plt.plot(myaircraft.mission.profile.Breaks,np.ones(6)*0.05, '*')
plt.grid(visible=True)
plt.xlabel('t [min]')
plt.ylabel('Efuel')
plt.show()

# %%
plt.plot(times,beta, 'b')
#plt.plot(myaircraft.mission.profile.Breaks,np.ones(6)*0.05, '*')
plt.grid(visible=True)
plt.xlabel('t [min]')
plt.ylabel('beta')
plt.show()

# %%
plt.plot(times/60,mission.profile.Altitude(times))
plt.grid(visible=True)
plt.xlabel('t [min]')
plt.ylabel('Altitude [m]')
plt.show()
